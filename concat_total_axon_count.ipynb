# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
axonlist_1 = pd.read_csv('/misc/torrey/onarvaez/Aqueronte_hist/is01/histology/nerve_left_degenerated/proc/total_axon_degenerated.csv')
axonlist_2 = pd.read_csv('/misc/torrey/onarvaez/Aqueronte_hist/is02/histology/nerve_left_degenerated/proc/total_axon_degenerated.csv')
axonlist_3 = pd.read_csv('/misc/torrey/onarvaez/Aqueronte_hist/is03/histology/nerve_right_degenerated/proc/total_axon_degenerated.csv')
axonlist_4 = pd.read_csv('/misc/torrey/onarvaez/Aqueronte_hist/is04/histology/nerve_left_degenerated/proc/total_axon_degenerated.csv')
axonlist_5 = pd.read_csv('/misc/torrey/onarvaez/Aqueronte_hist/is05/histology/nerve_right_degenerated/proc/total_axon_degenerated.csv')
axonlist_6 = pd.read_csv('/misc/torrey/onarvaez/Aqueronte_hist/is06/histology/nerve_left_degenerated/proc/total_axon_degenerated.csv')
axonlist_7 = pd.read_csv('/misc/torrey/onarvaez/Aqueronte_hist/is07/histology/nerve_right_degenerated/proc/total_axon_degenerated.csv')
axonlist_8 = pd.read_csv('/misc/torrey/onarvaez/Aqueronte_hist/is08/histology/nerve_right_degenerated/proc/total_axon_degenerated.csv')
axonlist_9 = pd.read_csv('/misc/torrey/onarvaez/Aqueronte_hist/is09/histology/nerve_right_degenerated/proc/total_axon_degenerated.csv')
axonlist_10 = pd.read_csv('/misc/torrey/onarvaez/Aqueronte_hist/is10/histology/nerve_right_degenerated/proc/total_axon_degenerated.csv')

# %%
total_all_concat = pd.concat([axonlist_1, axonlist_2, axonlist_3, axonlist_4, axonlist_5, axonlist_6, axonlist_7, axonlist_8, axonlist_9, axonlist_10])

# %%
total_all_concat
# Out:
#     Unnamed: 0  total_axon_degenerated
# 0            0                     250
# 1            1                     282
# 2            2                     245
# 3            3                     337
# 4            4                     255
# 5            5                     354
# 6            6                     346
# 7            7                     215
# 8            8                     257
# 9            9                     285
# 0            0                    1317
# 1            1                    1816
# 2            2                    1212
# 3            3                     799
# 4            4                     827
# 5            5                     863
# 6            6                     850
# 7            7                     791
# 8            8                     748
# 9            9                     692
# 0            0                     712
# 1            1                     631
# 2            2                     455
# ...

# %%
total_all_concat.to_csv('/misc/torrey/onarvaez/Aqueronte_hist/total_axon_nerve_degenerated.csv')
