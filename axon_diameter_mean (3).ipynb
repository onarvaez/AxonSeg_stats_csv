# %%
import pandas as pd

# %%
ax1 = pd.read_csv('C:\Users\Omar\pandas_training\ct01\histology\nerve_a_intact\proc\1_segmentation\stats_image')
ax2 = pd.read_csv('C:\Users\Omar\pandas_training\ct01\histology\nerve_a_intact\proc\1_segmentation\stats_image')
ax3 = pd.read_csv('C:\Users\Omar\pandas_training\ct01\histology\nerve_a_intact\proc\1_segmentation\stats_image')
ax4 = pd.read_csv('C:\Users\Omar\pandas_training\ct01\histology\nerve_a_intact\proc\1_segmentation\stats_image')
ax5 = pd.read_csv('C:\Users\Omar\pandas_training\ct01\histology\nerve_a_intact\proc\1_segmentation\stats_image')
ax6 = pd.read_csv('C:\Users\Omar\pandas_training\ct01\histology\nerve_a_intact\proc\1_segmentation\stats_image')
ax7 = pd.read_csv('C:\Users\Omar\pandas_training\ct01\histology\nerve_a_intact\proc\1_segmentation\stats_image')
ax8 = pd.read_csv('C:\Users\Omar\pandas_training\ct01\histology\nerve_a_intact\proc\1_segmentation\stats_image')
ax9 = pd.read_csv('C:\Users\Omar\pandas_training\ct01\histology\nerve_a_intact\proc\1_segmentation\stats_image')
ax10 = pd.read_csv('C:\Users\Omar\pandas_training\ct01\histology\nerve_a_intact\proc\1_segmentation\stats_image')
# Out:
#   File "<ipython-input-6-bc857a4a8eb2>", line 1
#     ax1 = pd.read_csv('C:\Users\Omar\pandas_training\ct01\histology\nerve_a_intact\proc\1_segmentation\stats_image')
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
ax1
# Out:
#    axon_diameter_mean  axon_diameter_median  axon_diameter_std  \
# 0            0.882346              0.844063           0.282489
#
#    axon_diameter_max  axon_diameter_min  myelin_diameter_mean  \
# 0           3.182489           0.423928              1.576874
#
#    myelin_diameter_median  myelin_diameter_std  myelin_diameter_max  \
# 0                1.488069             0.505016             4.646666
#
#    myelin_diameter_min     ...      myelin_thickness_mean  \
# 0             0.689175     ...                   0.347265
#
#    myelin_thickness_median  myelin_thickness_std  myelin_thickness_max  \
# 0                 0.321247              0.125934              1.105297
#
#    myelin_thickness_min  gRatio_mean  gRatio_median  gRatio_std  gRatio_max  \
# 0              0.121408     0.563379       0.565091    0.050142    0.790569
#
#    gRatio_min
# 0    0.391015
#
# [1 rows x 30 columns]

# %%
ax6
# Out:
#    axon_diameter_mean  axon_diameter_median  axon_diameter_std  \
# 0            0.854996              0.809121           0.260372
#
#    axon_diameter_max  axon_diameter_min  myelin_diameter_mean  \
# 0           3.030632           0.392481              1.560145
#
#    myelin_diameter_median  myelin_diameter_std  myelin_diameter_max  \
# 0                1.466344              0.48467             4.502145
#
#    myelin_diameter_min     ...      myelin_thickness_mean  \
# 0              0.71657     ...                   0.352575
#
#    myelin_thickness_median  myelin_thickness_std  myelin_thickness_max  \
# 0                 0.327233              0.126126              1.167901
#
#    myelin_thickness_min  gRatio_mean  gRatio_median  gRatio_std  gRatio_max  \
# 0              0.105662     0.551948       0.553718    0.050787    0.746998
#
#    gRatio_min
# 0    0.313552
#
# [1 rows x 30 columns]

# %%
pd.concat([ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10])
# Out:
#    axon_diameter_mean  axon_diameter_median  axon_diameter_std  \
# 0            0.882346              0.844063           0.282489
# 0            0.839715              0.805145           0.254615
# 0            0.913708              0.888517           0.268373
# 0            0.845968              0.797133           0.285320
# 0            0.892445              0.840252           0.315052
# 0            0.854996              0.809121           0.260372
# 0            0.863170              0.828715           0.265029
# 0            0.883383              0.832579           0.302311
# 0            0.871742              0.832579           0.264940
# 0            0.876721              0.836424           0.295976
#
#    axon_diameter_max  axon_diameter_min  myelin_diameter_mean  \
# 0           3.182489           0.423928              1.576874
# 0           3.153110           0.080115              1.513440
# 0           3.120371           0.400575              1.656678
# ...

# %%
ax_concat = pd.concat([ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10])

# %%
ax_concat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2d1ec1a78089> in <module>()
# ----> 1 ax_concat
#
# NameError: name 'ax_concat' is not defined

# %%
#concatenar todas las columnas. Ahora no

# %%
col_ax_concat = pd.concat([ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10], axis=0)

# %%
col_ax_concat
# Out:
#    axon_diameter_mean  axon_diameter_median  axon_diameter_std  \
# 0            0.882346              0.844063           0.282489
# 0            0.839715              0.805145           0.254615
# 0            0.913708              0.888517           0.268373
# 0            0.845968              0.797133           0.285320
# 0            0.892445              0.840252           0.315052
# 0            0.854996              0.809121           0.260372
# 0            0.863170              0.828715           0.265029
# 0            0.883383              0.832579           0.302311
# 0            0.871742              0.832579           0.264940
# 0            0.876721              0.836424           0.295976
#
#    axon_diameter_max  axon_diameter_min  myelin_diameter_mean  \
# 0           3.182489           0.423928              1.576874
# 0           3.153110           0.080115              1.513440
# 0           3.120371           0.400575              1.656678
# ...

# %%
ax_diameter_mean = ax_concat['axon_diameter_mean']

# %%
ax_diameter_mean
# Out:
# 0    0.882346
# 0    0.839715
# 0    0.913708
# 0    0.845968
# 0    0.892445
# 0    0.854996
# 0    0.863170
# 0    0.883383
# 0    0.871742
# 0    0.876721
# Name: axon_diameter_mean, dtype: float64

# %%
ax_diameter_mean.to_csv('/misc/torrey/onarvaez/TMP/pandas_training/ct01/histology/nerve_a_intact/proc/ax_diameter_mean.csv')

# %%
col_Names=["axon_diameter_mean"]
axon_diameter_mean= pd.read_csv('/misc/torrey/onarvaez/TMP/pandas_training/ct01/histology/nerve_a_intact/proc/ax_diameter_mean.csv',names=col_Names)

# %%
axon_diameter_mean
# Out:
#    axon_diameter_mean
# 0            0.882346
# 0            0.839715
# 0            0.913708
# 0            0.845968
# 0            0.892445
# 0            0.854996
# 0            0.863170
# 0            0.883383
# 0            0.871742
# 0            0.876721

# %%
axon_diameter_mean.to_csv('/misc/torrey/onarvaez/TMP/pandas_training/ct01/histology/nerve_a_intact/proc/axon_diameter_mean.csv')

# %%
dog = pd.read_csv('/misc/torrey/onarvaez/TMP/pandas_training/ct01/histology/nerve_a_intact/proc/total_axon.csv')

# %%
dog_1 = dog.drop('Unnamed: 0', axis=1)

# %%
dog_1
# Out:
#    total_axon
# 0        3201
# 1        3677
# 2        2749
# 3        3631
# 4        2828
# 5        2921
# 6        3292
# 7        3277
# 8        3398
# 9        3392

# %%
dog_1.to_csv('/misc/torrey/onarvaez/TMP/pandas_training/ct01/histology/nerve_a_intact/proc/dog_1.csv')

# %%
diam = pd.read_csv('/misc/torrey/onarvaez/TMP/pandas_training/ct01/histology/nerve_a_intact/proc/axon_diameter_mean.csv')

# %%
diam
# Out:
#    Unnamed: 0  axon_diameter_mean
# 0           0            0.882346
# 1           0            0.839715
# 2           0            0.913708
# 3           0            0.845968
# 4           0            0.892445
# 5           0            0.854996
# 6           0            0.863170
# 7           0            0.883383
# 8           0            0.871742
# 9           0            0.876721

# %%
diam_1 = diam.drop('Unnamed: 0', axis=1)

# %%
diam_1
# Out:
#    axon_diameter_mean
# 0            0.882346
# 1            0.839715
# 2            0.913708
# 3            0.845968
# 4            0.892445
# 5            0.854996
# 6            0.863170
# 7            0.883383
# 8            0.871742
# 9            0.876721

# %%
diam_1.to_csv('/misc/torrey/onarvaez/TMP/pandas_training/ct01/histology/nerve_a_intact/proc/axon_diam_1.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-2b99a234caae> in <module>()
# ----> 1 merge = dog_1.merge(diam_1, index='total_axon')
#
# TypeError: merge() got an unexpected keyword argument 'index'

# %%
merge
# Out:
# Empty DataFrame
# Columns: [total_axon, axon_diameter_mean]
# Index: []
